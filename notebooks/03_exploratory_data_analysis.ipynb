# %% [markdown]
# # Notebook 03: Exploratory Data Analysis & Statistical Visualizations
#
# **Objective**: Generate publication-quality visualizations in an academic silver/grey/graphite theme answering core research questions.
#
# ---

# %%
import os
import sys
sys.path.append("..")

import pandas as pd
import matplotlib.pyplot as plt
from src.data_loader import load_raw_data
from src.visualization import (
    plot_target_distribution, plot_numerical_distributions,
    plot_boxplots_and_outliers, plot_correlation_heatmap,
    plot_categorical_analysis
)
from src.preprocessing import run_preprocessing_pipeline

df = load_raw_data()
prep = run_preprocessing_pipeline(df, save_artifacts=False)

plot_target_distribution(df)
plot_numerical_distributions(df)
plot_boxplots_and_outliers(df)
plot_correlation_heatmap(prep["X_train_df"])
plot_categorical_analysis(df)
print("EDA Visualizations generated and saved to results/figures/")
